# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\prashant\House Predict.csv")
df
# Out:
#       x   y
# 0   500  20
# 1   750  30
# 2  1000  40
# 3  1250  50
# 4  1500  60

# %%
# %matplotlib inline
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x, df.y, color='yellow', marker='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[40]])
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.6])
