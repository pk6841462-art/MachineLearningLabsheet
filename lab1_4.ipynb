# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"D:\prashant\fuelprediction.csv")
df
# Out:
#      x   y
# 0  1.0  20
# 1  1.5  18
# 2  2.0  16
# 3  2.5  14
# 4  3.0  12

# %%
# %matplotlib inline
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(df.x, df.y, color='red', marker='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[1.5]])
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.])
